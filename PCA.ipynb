# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/R_intro/blob/main/PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Principal Component Analysis in R

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# install.packages("datasets")
# install.packages("dplyr")
# install.packages("pacman")

# %%
# %%R
# pacman::p_load(pacman,dplyr)

# %%
# %%R
# print(head(mtcars))
# # Select variables
# cars <- mtcars[, c(1:4, 6:7, 9:11)]
# head(cars)

# %%
# %%R
# # COMPUTE PCA ##############################################
#
# # For entire data frame ####################################
# pc <- prcomp(cars,
#         center = TRUE,  # Centers means to 0 (optional)
#         scale = TRUE)   # Sets unit variance (helpful)
#
# # To specify variables #####################################
#
# pc <- prcomp(~ mpg + cyl + disp + hp + wt + qsec + am +
#         gear + carb,
#         data = mtcars,
#         center = TRUE,
#         scale = TRUE)
#
# # Below is easier

# %%
# %%R
# # For entire data frame ####################################
# pc <- prcomp(cars,
#         center = TRUE,  # Centers means to 0 (optional)
#         scale = TRUE)   # Sets unit variance (helpful)
# summary(pc)
# Out:
# Importance of components:
#                           PC1    PC2     PC3     PC4     PC5     PC6     PC7
# Standard deviation     2.3391 1.5299 0.71836 0.46491 0.38903 0.35099 0.31714
# Proportion of Variance 0.6079 0.2601 0.05734 0.02402 0.01682 0.01369 0.01118
# Cumulative Proportion  0.6079 0.8680 0.92537 0.94939 0.96620 0.97989 0.99107
#                            PC8    PC9
# Standard deviation     0.24070 0.1499
# Proportion of Variance 0.00644 0.0025
# Cumulative Proportion  0.99750 1.0000

# %%
# %%R
# plot(pc)

# %%
# %%R
# # Show Principal Components values
# pc

# %%
# %%R
# # See how cases load on PCs
# predict(pc) %>% round(2)

# %%
# %%R
# biplot(pc)

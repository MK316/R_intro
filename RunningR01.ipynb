# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/R_intro/blob/main/RunningR01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Creating a Graph
attach(mtcars)
par(mfrow=c(2,2))
plot(wt, mpg)
abline(lm(mpg~wt))
title("Regression of MPG on Weight")
# Out:
# The following objects are masked from mtcars (pos = 3):
#
#     am, carb, cyl, disp, drat, gear, hp, mpg, qsec, vs, wt
#
#
# The following objects are masked from mtcars (pos = 4):
#
#     am, carb, cyl, disp, drat, gear, hp, mpg, qsec, vs, wt
#
#
# The following objects are masked from mtcars (pos = 5):
#
#     am, carb, cyl, disp, drat, gear, hp, mpg, qsec, vs, wt
# Plot with title “Regression of MPG on Weight”

# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/R_intro/blob/main/Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regression in R

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# install.packages("datasets")
# install.packages("pacman")

# %%
# %%R
# pacman::p_load(pacman, caret, lars, tidyverse)
# Out:
# R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: also installing the dependencies ‘listenv’, ‘parallelly’, ‘future’, ‘globals’, ‘future.apply’, ‘progressr’, ‘numDeriv’, ‘SQUAREM’, ‘lava’, ‘prodlim’, ‘proxy’, ‘iterators’, ‘Rcpp’, ‘gower’, ‘hardhat’, ‘ipred’, ‘timeDate’, ‘e1071’, ‘foreach’, ‘ModelMetrics’, ‘plyr’, ‘pROC’, ‘recipes’, ‘reshape2’
#
#
# R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/listenv_0.8.0.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 36762 bytes (35 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %%
# %%R
# # LOAD DATA ################################################
#
# ?USJudgeRatings
# head(USJudgeRatings)
# data <- USJudgeRatings

# %%
# %%R
# # Define variable groups
# x <- as.matrix(data[, -12])
# y <- data[, 12]

# %%
# %%R
# # REGRESSION WITH SIMULTANEOUS ENTRY #######################
#
# # Using variable groups
# reg1 <- lm(y ~ x) # predicted by x
#
# # Or specify variables individually
# # reg1 <- lm(RTEN ~ CONT + INTG + DMNR + DILG + CFMG +
# #            DECI + PREP + FAMI + ORAL + WRIT + PHYS,
# #            data = USJudgeRatings)

# %%
# %%R
# # Results
# reg1           # Coefficients only
# summary(reg1)  # Inferential tests
# # See Multiple R-squared value: 0.99 (great result)

# %%
# Python and colab doesn't match
# plt.rcParams['figure.figsize'] = [10, 5]

# %%
# %%R
#
# # MORE SUMMARIES ###########################################
#
# anova(reg1)            # Coefficients w/inferential tests
# coef(reg1)             # Coefficients (same as reg1)
# confint(reg1)          # CI for coefficients
# resid(reg1)            # Residuals case-by-case
# hist(residuals(reg1))  # Histogram of residuals

# %%
# %%R
# # ADDITIONAL MODELS ########################################
# p_load(lars, caret)

# %%
# %%R
# # Conventional stepwise regression
# stepwise <- lars(x, y, type = "stepwise")
#
# # Stagewise: Like stepwise but with better generalizability
# forward <- lars(x, y, type = "forward.stagewise")
#
# # LAR: Least Angle Regression
# lar <- lars(x, y, type = "lar")
#
# # LASSO: Least Absolute Shrinkage and Selection Operator
# lasso <- lars(x, y, type = "lasso")

# %%
# %%R
# # Comparison of R^2 for new models
# r2comp <- c(stepwise$R2[6], forward$R2[6],
#             lar$R2[6], lasso$R2[6]) %>%
#             round(2)
# names(r2comp) <- c("stepwise", "forward", "lar", "lasso")
# r2comp  # Show values of R^2
# Out:
# stepwise  forward      lar    lasso
#     0.99     0.99     0.99     0.99
